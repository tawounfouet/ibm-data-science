# %% [markdown]
# <h1>My Jupyter Notebook on IBM Watson Studio</h1>

# %% [markdown]
# **Dennis Lam**
#
# Current Occupation: Unemployed
#
# Desired Occupation: Data Science

# %% [markdown]
# *I'm interested in Data Science becuase it is exciting to mine for data insights and present results to people*

# %% [markdown]
# <h3>This code print a statement</h3>

# %%
print("Herramientas para la ciencia de datos")
# Out:
# Herramientas para la ciencia de datos

# %% [markdown]
# <blockquote>
#     <p>This is a blockquote.</p>
#
# </blockquote>
#
# <ul>
# <li>Candy.</li>
# <li>Gum.</li>
# <li>Booze.</li>
# </ul>

# %% [markdown]
# ![python_logo.svg](attachment:python_logo.svg)
